# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv(".\\price_paid_records.csv")
data.columns = data.columns.str.lower()

# %%
data
# Out:
#                    transaction unique identifier   price  date of transfer  \
# 0         {81B82214-7FBC-4129-9F6B-4956B4A663AD}   25000  1995-08-18 00:00
# 1         {8046EC72-1466-42D6-A753-4956BF7CD8A2}   42500  1995-08-09 00:00
# 2         {278D581A-5BF3-4FCE-AF62-4956D87691E6}   45000  1995-06-30 00:00
# 3         {1D861C06-A416-4865-973C-4956DB12CD12}   43150  1995-11-24 00:00
# 4         {DD8645FD-A815-43A6-A7BA-4956E58F1874}   18899  1995-06-23 00:00
# ...                                          ...     ...               ...
# 22489343  {4C4EE000-291A-1854-E050-A8C063054F34}  175000  2017-02-20 00:00
# 22489344  {4C4EE000-291B-1854-E050-A8C063054F34}  586945  2017-02-15 00:00
# 22489345  {4C4EE000-291C-1854-E050-A8C063054F34}  274000  2017-02-24 00:00
# 22489346  {4C4EE000-291D-1854-E050-A8C063054F34}   36000  2017-02-22 00:00
# 22489347  {4C4EE000-291E-1854-E050-A8C063054F34}  145000  2017-03-03 00:00
#
# ...

# %%
# Histogram of price distribution
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Limit the x-axis to focus on the main distribution
price_cap = data['price'].quantile(0.99)
filtered_prices = data[data['price'] <= price_cap]

# Plot with log scale and aesthetic improvements
sns.histplot(filtered_prices['price'], bins=100, kde=True, color="skyblue", edgecolor="black")
plt.xscale('log')  # Log-transform the x-axis for better visibility of lower prices

# Title and labels
plt.title('Log-Scaled Price Distribution (Capped at 99th Percentile)', fontsize=16)
plt.xlabel('Price (log scale)', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the plot
plt.show()

# %%
# Box plot of price distribution
plt.figure(figsize=(12, 8))
sns.set_theme(style="whitegrid")

# Customizing the box plot
sns.boxplot(x='price', data=data, palette="Set2")
plt.xscale('log')  # Log-transform the x-axis for better visibility of lower prices

# Adding title and labels
plt.title('Log-Scaled Price Box Plot', fontsize=16)
plt.xlabel('Price (log scale)', fontsize=12)

# Show the plot
plt.show()
# Out:
# C:\Users\woutp\AppData\Local\Temp\ipykernel_11008\1605566722.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='price', data=data, palette="Set2")

# %%
# Histogram of price distribution
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Limit the x-axis to focus on the main distribution
price_cap = data['price'].quantile(0.99)
filtered_prices = data[data['price'] <= price_cap]

# Plot with log scale and aesthetic improvements
sns.histplot(filtered_prices['price'], bins=100, kde=True, color="skyblue", edgecolor="black")
plt.xscale('log')  # Log-transform the x-axis for better visibility of lower prices

# Title and labels
plt.title('Log-Scaled Price Distribution (Capped at 99th Percentile)', fontsize=16)
plt.xlabel('Price (log scale)', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the plot
plt.show()

# %%
# Box plot of price distribution
plt.figure(figsize=(12, 8))
sns.set_theme(style="whitegrid")

# Customizing the box plot
sns.boxplot(x='price', data=data, palette="Set2")
plt.xscale('log')  # Log-transform the x-axis for better visibility of lower prices

# Adding title and labels
plt.title('Log-Scaled Price Box Plot', fontsize=16)
plt.xlabel('Price (log scale)', fontsize=12)

# Show the plot
plt.show()
# Out:
# C:\Users\woutp\AppData\Local\Temp\ipykernel_11008\1605566722.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='price', data=data, palette="Set2")

# %%
# Density plot of price distribution
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Plot with log scale and aesthetic improvements
sns.kdeplot(filtered_prices['price'], shade=True, color="skyblue")
plt.xscale('log')  # Log-transform the x-axis for better visibility of lower prices

# Adding title and labels
plt.title('Log-Scaled Price Density Plot', fontsize=16)
plt.xlabel('Price (log scale)', fontsize=12)
plt.ylabel('Density', fontsize=12)

# Show the plot
plt.show()
# Out:
# C:\Users\woutp\AppData\Local\Temp\ipykernel_11008\1959338942.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(filtered_prices['price'], shade=True, color="skyblue")

# %%
# Time series plot of price over time

data['date of transfer'] = pd.to_datetime(data['date of transfer'])
data.set_index('date of transfer').resample('M')['price'].mean().plot(figsize=(12, 6))
plt.title('Average Price Over Time')
plt.ylabel('Average Price')
plt.xlabel('Date')
plt.show()
# Plotting price trends for each district over time
plt.figure(figsize=(14, 8))

# Group by date and district, then calculate the mean price
district_prices = data.groupby([data['date of transfer'].dt.to_period('M'), 'district'])['price'].mean().unstack()

# Plot each district's price trend
for district in district_prices.columns:
    plt.plot(district_prices.index.to_timestamp(), district_prices[district], label=district)

# Adding title and labels
plt.title('Average Price Over Time by District')
plt.ylabel('Average Price')
plt.xlabel('Date')
plt.legend(title='District', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Heat map of price over time

data['year'] = data['date of transfer'].dt.year
data['month'] = data['date of transfer'].dt.month
pivot = data.pivot_table(values='price', index='year', columns='month', aggfunc='mean')
plt.figure(figsize=(12, 8))
sns.heatmap(pivot, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title('Average Price by Year and Month')
plt.xlabel('Month')
plt.ylabel('Year')
plt.show()

# %%
# Box plot of price by property type
plt.figure(figsize=(12, 8))
sns.set_theme(style="whitegrid")

# Customizing the box plot with palette and order
sns.boxplot(x='property type', y='price', data=data, palette="Set3")
plt.yscale('log')  # Log-transform the y-axis for better visibility of lower prices

# Adding title and labels with improved font sizes
plt.title('Log-Scaled Price Distribution by Property Type', fontsize=16)
plt.xlabel('Property Type', fontsize=14)
plt.ylabel('Price (log scale)', fontsize=14)

# Rotating x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# C:\Users\woutp\AppData\Local\Temp\ipykernel_11008\3909770649.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='property type', y='price', data=data, palette="Set3")

# %%
# Bar plot of average price by property type
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")

# Use a subset of the data for quicker loading
subset_data = data.sample(n=10000, random_state=1)

# Create the bar plot without confidence intervals
sns.barplot(x='property type', y='price', data=subset_data, ci=None, palette="Set2")

# Adding title and labels
plt.title('Average Price by Property Type', fontsize=16)
plt.xlabel('Property Type', fontsize=14)
plt.ylabel('Average Price', fontsize=14)

# Rotating x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# C:\Users\woutp\AppData\Local\Temp\ipykernel_11008\2656609591.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='property type', y='price', data=subset_data, ci=None, palette="Set2")
# C:\Users\woutp\AppData\Local\Temp\ipykernel_11008\2656609591.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='property type', y='price', data=subset_data, ci=None, palette="Set2")

# %%
#Average price of top 10 towns/cities
top_towns = data['town/city'].value_counts().head(10).index
plt.figure(figsize=(12, 6))
sns.barplot(x='town/city', y='price', ci=None, data=data[data['town/city'].isin(top_towns)], estimator='mean')
plt.title('Average Price by Town/City')
plt.xlabel('Town/City')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\woutp\AppData\Local\Temp\ipykernel_11008\185029926.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='town/city', y='price', ci=None, data=data[data['town/city'].isin(top_towns)], estimator='mean')

# %%
# Box plot of price by new vs. old properties

plt.figure(figsize=(12, 8))
sns.set_theme(style="whitegrid")

# Customizing the box plot with palette and order
sns.boxplot(x='old/new', y='price', data=data, palette="Set3")
plt.yscale('log')  # Log-transform the y-axis for better visibility of lower prices

# Adding title and labels with improved font sizes
plt.title('Log-Scaled Price Distribution by New vs. Old Properties', fontsize=16)
plt.xlabel('New or Old', fontsize=14)
plt.ylabel('Price (log scale)', fontsize=14)

# Show the plot
plt.show()
# Out:
# C:\Users\woutp\AppData\Local\Temp\ipykernel_11008\2060374035.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='old/new', y='price', data=data, palette="Set3")

# %%
# Bar plot of price by new vs. old properties

plt.figure(figsize=(8, 6))

# Use a subset of the data for quicker loading
subset_data = data.sample(n=10000, random_state=1)

sns.barplot(x='old/new', y='price', ci=None, data=subset_data, estimator='mean')
plt.title('Average Price by New vs. Old Properties')
plt.xlabel('New or Old')
plt.ylabel('Average Price')
plt.show()
z
# Out:
# C:\Users\woutp\AppData\Local\Temp\ipykernel_11008\1935127225.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='old/new', y='price', ci=None, data=subset_data, estimator='mean')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 13
#      11 plt.ylabel('Average Price')
#      12 plt.show()
# ---> 13 z
#
# NameError: name 'z' is not defined

# %%
# Line plot of Monthly Trends by Category
# Line plot of Monthly Trends by District

monthly_prices_district = data.groupby([data['date of transfer'].dt.to_period('M'), 'district'])['price'].mean().unstack()
monthly_prices_district.plot(figsize=(12, 6))
plt.title('Monthly Average Price by District')
plt.ylabel('Average Price')
plt.xlabel('Month')
plt.legend(title='District', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Line plot of Monthly Trends by Category
# ----> 3 data['date of transfer'] = pd.to_datetime(data['date of transfer'])
#       4 monthly_prices = data.groupby([data['date of transfer'].dt.to_period('M'), 'ppdcategory type'])['price'].mean().unstack()
#       5 monthly_prices.plot(figsize=(12, 6))
#
# NameError: name 'pd' is not defined

# %%
cor_data = data.drop(columns=['transaction unique identifier', 'date of transfer'])
data['property type'] = LabelEncoder().fit_transform(data['property type'])
data['old/new'] = LabelEncoder().fit_transform(data['old/new'])
data['duration'] = LabelEncoder().fit_transform(data['duration'])
data['town/city'] = LabelEncoder().fit_transform(data['town/city'])
data['district'] = LabelEncoder().fit_transform(data['district'])
data['county'] = LabelEncoder().fit_transform(data['county'])
data['ppdcategory type'] = LabelEncoder().fit_transform(data['ppdcategory type'])
data['record status - monthly file only'] = LabelEncoder().fit_transform(data['record status - monthly file only'])
data.drop(columns=['transaction unique identifier'])
# Compute the correlation matrix
correlation_matrix = cor_data.corr()

price_correlation = correlation_matrix[['price']].sort_values(by='price', ascending=False).drop('price')
plt.figure(figsize=(8, 6))
sns.heatmap(price_correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation with Survived')
plt.show()
